# %%
import pandas as pd
import numpy as np

# %% [markdown]
# importing the first data set, domestic_visitors_2016

# %%
dom_vis_2016 = pd.read_csv("data_visitors/domestic_visitors/domestic_visitors_2016.csv")

# %%
dom_vis_2016.head()
# Out:
#    district        date     month  year visitors
# 0  Adilabad  01-01-2016   January  2016   792136
# 1  Adilabad  01-02-2016  February  2016   937820
# 2  Adilabad  01-03-2016     March  2016   582946
# 3  Adilabad  01-04-2016     April  2016   341948
# 4  Adilabad  01-05-2016       May  2016   252887

# %%
dom_vis_2016.dtypes
# Out:
# district    object
# date        object
# month       object
# year         int64
# visitors    object
# dtype: object

# %%
dom_vis_2016.visitors
# Out:
# 0      792136
# 1      937820
# 2      582946
# 3      341948
# 4      252887
#         ...
# 367
# 368
# 369    584800
# 370    681000
# 371    462800
# Name: visitors, Length: 372, dtype: object

# %% [markdown]
# searching the data frame with particular district names doesn't show any contents. I am trying to troubleshoot that. Later understood that it's because some entries in visitors column is ' ' .

# %%
df_jagtial = dom_vis_2016.loc[dom_vis_2016['district']=="Jagtial"]
print(df_jagtial.isnull().any().any())
# Out:
# False

# %%
print(dom_vis_2016.isnull().any().any())
# Out:
# False

# %%
mask = dom_vis_2016.isin(['NA', 'N/A']).any(axis=1)
df_na = dom_vis_2016.loc[mask]

# %%
print(dom_vis_2016["visitors"].isnull().any().any())
# Out:
# False

# %%
dom_vis_2016['visitors'].iloc[12]
# Out:
# 0

# %%
dom_vis_2016.iloc[9:20]
# Out:
#                  district        date     month  year  visitors
# 9                Adilabad  01-10-2016   October  2016     94184
# 10               Adilabad  01-11-2016  November  2016     99148
# 11               Adilabad  01-12-2016  December  2016     53125
# 12  Bhadradri Kothagudem   01-01-2016   January  2016         0
# 13  Bhadradri Kothagudem   01-02-2016  February  2016         0
# 14  Bhadradri Kothagudem   01-03-2016     March  2016         0
# 15  Bhadradri Kothagudem   01-04-2016     April  2016         0
# 16  Bhadradri Kothagudem   01-05-2016       May  2016         0
# 17  Bhadradri Kothagudem   01-06-2016      June  2016         0
# 18  Bhadradri Kothagudem   01-07-2016      July  2016         0
# 19  Bhadradri Kothagudem   01-08-2016    August  2016         0

# %%
dom_vis_2016.loc[dom_vis_2016['district']=="Karimnagar"]
# Out:
# Empty DataFrame
# Columns: [district, date, month, year, visitors]
# Index: []

# %%
dom_vis_2016.iloc[12:99]
# Out:
#                  district        date     month  year  visitors
# 12  Bhadradri Kothagudem   01-01-2016   January  2016         0
# 13  Bhadradri Kothagudem   01-02-2016  February  2016         0
# 14  Bhadradri Kothagudem   01-03-2016     March  2016         0
# 15  Bhadradri Kothagudem   01-04-2016     April  2016         0
# 16  Bhadradri Kothagudem   01-05-2016       May  2016         0
# ..                    ...         ...       ...   ...       ...
# 94             Kamareddy   01-11-2016  November  2016        38
# 95             Kamareddy   01-12-2016  December  2016        42
# 96            Karimnagar   01-01-2016   January  2016   1984442
# 97            Karimnagar   01-02-2016  February  2016    779960
# 98            Karimnagar   01-03-2016     March  2016   1018399
#
# [87 rows x 5 columns]

# %%
dom_vis_2016["visitors"]= dom_vis_2016["visitors"].astype("Int64")

# %%
dom_vis_2016.dtypes
# Out:
# district    object
# date        object
# month       object
# year         int64
# visitors     Int64
# dtype: object

# %%
dom_vis_2016.loc[dom_vis_2016['district']=='Jangaon']
# Out:
# Empty DataFrame
# Columns: [district, date, month, year, visitors]
# Index: []

# %%
dom_vis_2016.to_csv('pthon_2016',index=True)

# %%
dom_vis_2017=pd.read_csv('data_visitors/domestic_visitors/domestic_visitors_2017.csv')

# %%
dom_vis_2017.head()
# Out:
#    district        date     month  year visitors
# 0  Adilabad  01-01-2017   January  2017   318799
# 1  Adilabad  01-02-2017  February  2017    83316
# 2  Adilabad  01-03-2017     March  2017    27508
# 3  Adilabad  01-04-2017     April  2017    13946
# 4  Adilabad  01-05-2017       May  2017    11752

# %%
dom_vis_2017.dtypes
# Out:
# district    object
# date        object
# month       object
# year         int64
# visitors    object
# dtype: object

# %%
dom_vis_2017['visitors']=dom_vis_2017['visitors'].replace(' ',0)

# %%
dom_vis_2017.iloc[12:20]
# Out:
#                  district        date     month  year visitors
# 12  Bhadradri Kothagudem   01-01-2017   January  2017   302315
# 13  Bhadradri Kothagudem   01-02-2017  February  2017   251359
# 14  Bhadradri Kothagudem   01-03-2017     March  2017   243943
# 15  Bhadradri Kothagudem   01-04-2017     April  2017   667459
# 16  Bhadradri Kothagudem   01-05-2017       May  2017   311626
# 17  Bhadradri Kothagudem   01-06-2017      June  2017   351742
# 18  Bhadradri Kothagudem   01-07-2017      July  2017   258114
# 19  Bhadradri Kothagudem   01-08-2017    August  2017   316438

# %%
melted_df = pd.melt(dom_vis_2016, id_vars=['district'], value_vars=['January', 'February', 'March','April'], var_name='month', value_name='visitors_16')
# Out:
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[13], line 1
#
# ----> 1 melted_df = pd.melt(dom_vis_2016, id_vars=['district'], value_vars=['January', 'February', 'March','April'], var_name='month', value_name='visitors_16')
#
#
#
# File c:\Users\azifn\anaconda3\envs\myenv\lib\site-packages\pandas\core\reshape\melt.py:96, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#
#      94     missing = Index(com.flatten(value_vars)).difference(cols)
#
#      95     if not missing.empty:
#
# ---> 96         raise KeyError(
#
#      97             "The following 'value_vars' are not present in "
#
#      98             f"the DataFrame: {list(missing)}"
#
#      99         )
#
#     100 if col_level is not None:
#
#     101     idx = frame.columns.get_level_values(col_level).get_indexer(
#
#     102         id_vars + value_vars
#
# ...

# %% [markdown]
# Sorting the data with respect to district, and visitors in each month

# %%
pivoted_dom_vis_2016= dom_vis_2016.pivot(index='district', columns='month',values='visitors')

# %%
pivoted_dom_vis_2016
# Out:
# month                       April   August December  February  January  \
# district
# Adilabad                   341948   614285    53125    937820   792136
# Bhadradri Kothagudem                         326770
# Hyderabad                 1127738  1061137  1225502    778748  1122510
# Jagtial                                      207294
# Jangaon                                       12680
# Jayashankar Bhoopalpally                      85460
# Jogulamba Gadwal                             182333
# Kamareddy                                        42
# Karimnagar                 956959  1018399    13890    779960  1984442
# Khammam                    971622   503654   116403    407533   651827
# Komaram Bheem Asifabad                            0
# Mahabubabad                                   12955
# Mahbubnagar                622432  1133105   210202   1312068   577071
# Mancherial                                     2423
# ...

# %% [markdown]
# changing the column order to follow the monthly order.

# %%
column_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ordered_16 = pivoted_dom_vis_2016.reindex(column_order, axis=1)

# %%
ordered_16
# Out:
# month                     January  February    March    April      May  \
# district
# Adilabad                   792136    937820   582946   341948   252887
# Bhadradri Kothagudem
# Hyderabad                 1122510    778748  1017794  1127738  1287181
# Jagtial
# Jangaon
# Jayashankar Bhoopalpally
# Jogulamba Gadwal
# Kamareddy
# Karimnagar                1984442    779960  1018399   956959  1095642
# Khammam                    651827    407533   458527   971622   433994
# Komaram Bheem Asifabad
# Mahabubabad
# Mahbubnagar                577071   1312068  1731983   622432   571898
# Mancherial
# Medak                       92600    215000  1318000   300000   198000
# Medchal
# Nagarkurnool
# Nalgonda                   566515    539467   619462   601253   628872
# Nirmal
# Nizamabad                     576       869      408      476      554
# Peddapalli
# Rajanna Sircilla
# Ranga Reddy
# Sangareddy
# Siddipet
# Suryapet
# Vikarabad
# Wanaparthy
# Warangal (Rural)
# ...

# %%
pivoted_dom_vis_2017= dom_vis_2017.pivot(index='district',columns='month',values='visitors')

# %%
column_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ordered_17 = pivoted_dom_vis_2017.reindex(column_order, axis=1)

# %%
ordered_17
# Out:
# month                     January February    March    April      May  \
# district
# Adilabad                   318799    83316    27508    13946    11752
# Bhadradri Kothagudem       302315   251359   243943   667459   311626
# Hyderabad                 1924695  1886698  1783903  2366793  2266793
# Jagtial                    174477   159659   323658   330540   468038
# Jangaon                     12280    12610     8450     9788    12130
# Jayashankar Bhoopalpally    96560    96850    81400    90700    91150
# Jogulamba Gadwal           214887   481110   155013   131426   131426
# Kamareddy                      58       50       41       46       60
# Karimnagar                  14425    10845     9625     8630     8890
# Khammam                    132528   115470   101878   135920   138799
# Komaram Bheem Asifabad       2241     2490     2767     3074     3416
# Mahabubabad                 13260    13045     9100     9140    10220
# ...

# %%
dom_vis_2018=pd.read_csv('data_visitors/domestic_visitors/domestic_visitors_2018.csv')

# %%
pivoted_dom_vis_2018= dom_vis_2018.pivot(index='district',columns='month',values='visitors')

# %%
column_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ordered_18 = pivoted_dom_vis_2018.reindex(column_order, axis=1)

# %%
ordered_18
# Out:
# month                     January February    March    April      May  \
# district
# Adilabad                   320356    36550    23011    14183     8197
# Bhadradri Kothagudem       421275   240634   421275   341258   291273
# Hyderabad                 1978396  1365837  1415938  1586375  1189492
# Jagtial                    614082   349576   416716   372874   641363
# Jangaon                     17180    18600    17300    18100    19660
# Jayashankar Bhoopalpally  6519850  8626250   146150   149150   152050
# Jogulamba Gadwal           146441   481110   155013   138673   131426
# Kamareddy                      44       44       45       45       49
# Karimnagar                  13505     9330     7205     5830     5689
# Khammam                    110094   104444   127152   126553   135189
# Komaram Bheem Asifabad       2863     2736     1826      868      793
# Mahabubabad                 14000    14230    13110    12915    12865
# ...

# %%
dom_vis_2019= pd.read_csv('data_visitors/domestic_visitors/domestic_visitors_2019.csv')

# %%
pivoted_dom_vis_2019= dom_vis_2019.pivot(index='district',columns='month',values='visitors')

# %%
pivoted_dom_vis_2019
# Out:
# month                       April   August December February  January  \
# district
# Adilabad                     9972   108173    38089   406177    25071
# Bhadradri Kothagudem       349585   271941   287328   229159   283365
# Hyderabad                 1045933  1121380  1277569   983147  1426500
# Jagtial                    447226   151570   372959   215105   211913
# Jangaon                     26160    27800    28460    28810    28750
# Jayashankar Bhoopalpally    38500    45000    45800    33500   197430
# Jogulamba Gadwal            82334   123733   182333   481110   146441
# Kamareddy                      41       50       45       41       42
# Karimnagar                   5623     5480     7898     6480    10285
# Khammam                    135920   111374   124525    98471   123550
# Komaram Bheem Asifabad        663     2572     2783     1449     2476
# Mahabubabad                 12980    12190    12360    13545    13480
# ...

# %%
column_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ordered_19 = pivoted_dom_vis_2019.reindex(column_order, axis=1)

# %%
ordered_16.dtypes
# Out:
# month
# January      object
# February     object
# March        object
# April        object
# May          object
# June         object
# July         object
# August       object
# September    object
# October      object
# November     object
# December     object
# dtype: object

# %%
ordered_16.to_csv('ordered_16.csv',index=True)

# %%
ordered_17.to_csv('ordered_17.csv',index=True)

# %%
ordered_18.to_csv('ordered_18.csv',index=True)
ordered_19.to_csv('ordered_19.csv',index=True)

# %% [markdown]
# Dropping the districts which doesn't have entries in four years record.

# %%
ordered_16=pd.read_csv('ordered_16.csv')
ordered_17=pd.read_csv('ordered_17.csv')
ordered_18=pd.read_csv('ordered_18.csv')
ordered_19=pd.read_csv('ordered_19.csv')

# %% [markdown]
# Dropping the districts which doesn't have entries in four years record. The districts are 'Suryapet', 'Vikarabad','Ranga Reddy'and 'Medchal'

# %%
ordered_16_1=ordered_16.drop(15)
ordered_16_1=ordered_16_1.drop(22)
ordered_16_1=ordered_16_1.drop(25)
ordered_16_1=ordered_16_1.drop(26)

# %%
ordered_16_1
# Out:
#                     district  January  February    March    April      May  \
# 0                   Adilabad   792136    937820   582946   341948   252887
# 1      Bhadradri Kothagudem
# 2                  Hyderabad  1122510    778748  1017794  1127738  1287181
# 3                   Jagtial
# 4                   Jangaon
# 5   Jayashankar Bhoopalpally
# 6          Jogulamba Gadwal
# 7                 Kamareddy
# 8                Karimnagar   1984442    779960  1018399   956959  1095642
# 9                    Khammam   651827    407533   458527   971622   433994
# 10    Komaram Bheem Asifabad
# 11              Mahabubabad
# 12               Mahbubnagar   577071   1312068  1731983   622432   571898
# 13                Mancherial
# 14                    Medak     92600    215000  1318000   300000   198000
# 16             Nagarkurnool
# 17                  Nalgonda   566515    539467   619462   601253   628872
# 18                    Nirmal
# ...

# %%
ordered_17_1=ordered_17.drop(15)
ordered_17_1=ordered_17_1.drop(22)
ordered_17_1=ordered_17_1.drop(25)
ordered_17_1=ordered_17_1.drop(26)

# %%
ordered_18_1=ordered_18.drop(15)
ordered_18_1=ordered_18_1.drop(22)
ordered_18_1=ordered_18_1.drop(25)
ordered_18_1=ordered_18_1.drop(26)

# %%
ordered_19
# Out:
#                     district  January February    March    April      May  \
# 0                   Adilabad    25071   406177    14347     9972     6997
# 1      Bhadradri Kothagudem    283365   229159   225448   349585   275800
# 2                  Hyderabad  1426500   983147  1009991  1045933  1305748
# 3                   Jagtial    211913   215105   194090   447226   500206
# 4                   Jangaon     28750    28810    27300    26160    26740
# 5   Jayashankar Bhoopalpally   197430    33500    37500    38500    30800
# 6          Jogulamba Gadwal    146441   481110   155013    82334   154609
# 7                 Kamareddy        42       41       45       41       46
# 8                Karimnagar     10285     6480     6634     5623     3393
# 9                    Khammam   123550    98471    91340   135920   130971
# 10    Komaram Bheem Asifabad     2476     1449     1212      663      493
# 11              Mahabubabad     13480    13545    13490    12980    11970
# ...

# %%
ordered_19_1=ordered_19.drop(15)
ordered_19_1=ordered_19_1.drop(24)
ordered_19_1=ordered_19_1.drop(27)
ordered_19_1=ordered_19_1.drop(28)

# %%
ordered_16_1.to_csv('ordered_16_1.csv')

# %%
ordered_17_1.to_csv('ordered_17_1.csv')
ordered_18_1.to_csv('ordered_18_1.csv')
ordered_19_1.to_csv('ordered_19_1.csv')

# %% [markdown]
# Adding a column "Year" to all four data frames.

# %%
ordered_16_1['Year']= 2016

# %%
ordered_17_1["Year"]=2017
ordered_18_1['Year']=2018
ordered_19_1['Year']=2019

# %%
ordered_16_1.to_csv('ordered_16_1.csv')
ordered_17_1.to_csv('ordered_17_1.csv')
ordered_18_1.to_csv('ordered_18_1.csv')
ordered_19_1.to_csv('ordered_19_1.csv')

# %% [markdown]
# Merging all into one data frame.

# %%
merged_16_17_18_19= pd.concat([merged_16_17,ordered_18_1,ordered_19_1],axis=0,ignore_index=True)

# %%
merged_16_17_18_19.to_csv('merged_16_17_18_19.csv')

# %%
print(merged_16_17_18_19.isnull().sum())
# Out:
# district     0
# January      1
# February     1
# March        1
# April        1
# May          1
# June         1
# July         0
# August       0
# September    0
# October      0
# November     0
# December     0
# Year         0
# dtype: int64

# %%
merged_16_17_18_19.replace(' ',np.nan,inplace=True)

# %% [markdown]
# Changing data types of visitors of each month to Int64 from object.

# %%
merged_16_17_18_19['January']=merged_16_17_18_19['January'].astype('Int64')

# %%
merged_16_17_18_19=merged_16_17_18_19.astype({'February':'Int64','March':'Int64','April':'Int64','May':'Int64','June':'Int64','July':'Int64','August':'Int64','September':'Int64','October':'Int64','November':'Int64','December':'Int64'})

# %% [markdown]
# I am droping the year column to find the mean of all columns.

# %%
df=merged_16_17_18_19.drop('Year',axis=1)

# %%
mean = df.mean(axis=1,skipna=True)
df = df.assign(mean=mean)
# Out:
# C:\Users\azifn\AppData\Local\Temp\ipykernel_9768\2887542851.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = df.mean(axis=1,skipna=True)

# %%
df
# Out:
#                   district  January  February    March    April      May  \
# 0                 Adilabad   792136    937820   582946   341948   252887
# 1    Bhadradri Kothagudem      <NA>      <NA>     <NA>     <NA>     <NA>
# 2                Hyderabad  1122510    778748  1017794  1127738  1287181
# 3                 Jagtial      <NA>      <NA>     <NA>     <NA>     <NA>
# 4                 Jangaon      <NA>      <NA>     <NA>     <NA>     <NA>
# ..                     ...      ...       ...      ...      ...      ...
# 105               Siddipet   140793    199549   204600   184412   110500
# 106            Wanaparthy     28131     22342    20050    23749    20010
# 107       Warangal (Rural)    28700     28800    29000    26900    24900
# 108       Warangal (Urban)   151545    157755   154305   150425   143230
# 109        Yadadri Bhongir   479293     56525   481923   441150   345790
#
#          June     July   August  September  October  November  December  \
# ...

# %%
df.to_csv('merged_mean')

# %%
import pandas as pd
merged_16_17_18_19 =pd.read_csv('merged_16_17_18_19.csv')
df= pd.read_csv('merged_mean.csv')

# %% [markdown]
# Adding back the Year column.

# %%
df1= pd.concat([merged_16_17_18_19['Year'],df],axis=1)

# %%
df1
# Out:
#      Year  Unnamed: 0               district    January  February      March  \
# 0    2016           0               Adilabad   792136.0  937820.0   582946.0
# 1    2016           1  Bhadradri Kothagudem         NaN       NaN        NaN
# 2    2016           2              Hyderabad  1122510.0  778748.0  1017794.0
# 3    2016           3               Jagtial         NaN       NaN        NaN
# 4    2016           4               Jangaon         NaN       NaN        NaN
# ..    ...         ...                    ...        ...       ...        ...
# 105  2019         105               Siddipet   140793.0  199549.0   204600.0
# 106  2019         106            Wanaparthy     28131.0   22342.0    20050.0
# 107  2019         107       Warangal (Rural)    28700.0   28800.0    29000.0
# 108  2019         108       Warangal (Urban)   151545.0  157755.0   154305.0
# 109  2019         109        Yadadri Bhongir   479293.0   56525.0   481923.0
#
# ...

# %%
df1.dr
# Out:
# Index(['Year', 'Unnamed: 0', 'district', 'January', 'February', 'March',
#        'April', 'May', 'June', 'July', 'August', 'September', 'October',
#        'November', 'December', 'mean'],
#       dtype='object')

# %% [markdown]
# Changing the position of the column "Year".

# %%
col=df1.pop('Year')
df1.insert(14,col.name,col)

# %%
df1=df1.drop('Unnamed: 0',axis=1)

# %%
df1
# Out:
#                   district    January  February      March      April  \
# 0                 Adilabad   792136.0  937820.0   582946.0   341948.0
# 1    Bhadradri Kothagudem         NaN       NaN        NaN        NaN
# 2                Hyderabad  1122510.0  778748.0  1017794.0  1127738.0
# 3                 Jagtial         NaN       NaN        NaN        NaN
# 4                 Jangaon         NaN       NaN        NaN        NaN
# ..                     ...        ...       ...        ...        ...
# 105               Siddipet   140793.0  199549.0   204600.0   184412.0
# 106            Wanaparthy     28131.0   22342.0    20050.0    23749.0
# 107       Warangal (Rural)    28700.0   28800.0    29000.0    26900.0
# 108       Warangal (Urban)   151545.0  157755.0   154305.0   150425.0
# 109        Yadadri Bhongir   479293.0   56525.0   481923.0   441150.0
#
#            May        June       July     August  September  October  \
# ...

# %% [markdown]
# This is the (1/2) cleaned data frame used for analysis and visualisation in PowerBi.

# %%
df1.to_csv('df_final.csv')

# %%
df1=df1.melt(id_vars=['district'],var_name='Month',value_name='visitors')

# %%
df1=pd.read_csv('df_final.csv')

# %%
df1
# Out:
#      Unnamed: 0               district    January  February      March  \
# 0             0               Adilabad   792136.0  937820.0   582946.0
# 1             1  Bhadradri Kothagudem         NaN       NaN        NaN
# 2             2              Hyderabad  1122510.0  778748.0  1017794.0
# 3             3               Jagtial         NaN       NaN        NaN
# 4             4               Jangaon         NaN       NaN        NaN
# ..          ...                    ...        ...       ...        ...
# 105         105               Siddipet   140793.0  199549.0   204600.0
# 106         106            Wanaparthy     28131.0   22342.0    20050.0
# 107         107       Warangal (Rural)    28700.0   28800.0    29000.0
# 108         108       Warangal (Urban)   151545.0  157755.0   154305.0
# 109         109        Yadadri Bhongir   479293.0   56525.0   481923.0
#
#          April        May        June       July     August  September  \
# ...

# %%
df1=df1.drop('Unnamed: 0',axis=1)

# %%
df2= df1.melt(id_vars=['district','Year','mean'],var_name='month',value_name='Visitors')

# %% [markdown]
# This is the (2/2) cleaned data frame used for analysis and visualisation in PowerBi.

# %%
df2
# Out:
#                    district  Year          mean     month   Visitors
# 0                  Adilabad  2016  4.229631e+05   January   792136.0
# 1     Bhadradri Kothagudem   2016  2.963433e+05   January        NaN
# 2                 Hyderabad  2016  1.949559e+06   January  1122510.0
# 3                  Jagtial   2016  2.076923e+05   January        NaN
# 4                  Jangaon   2016  1.355333e+04   January        NaN
# ...                     ...   ...           ...       ...        ...
# 1315               Siddipet  2019  2.489887e+05  December   217930.0
# 1316            Wanaparthy   2019  2.488658e+04  December    20556.0
# 1317       Warangal (Rural)  2019  2.945833e+04  December    32050.0
# 1318       Warangal (Urban)  2019  1.496025e+05  December   147700.0
# 1319        Yadadri Bhongir  2019  3.741145e+05  December   477635.0
#
# [1320 rows x 5 columns]

# %%
df2.to_csv('df2_final.csv')
